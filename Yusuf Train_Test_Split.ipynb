# %%
# %matplotlib inline
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import datetime
import math

# %%
df = pd.read_csv('bike.csv')

# %%
print(len(df))
# Out:
# 2092573

# %%
df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                 174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                 759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                 615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                 761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...               ...                       ...                       ...
# 2092568           729  2019-10-31 23:59:12.1900  2019-11-01 00:11:21.4860
# 2092569           645  2019-10-31 23:59:17.0470  2019-11-01 00:10:02.9450
# 2092570           257  2019-10-31 23:59:22.5140  2019-11-01 00:03:40.2600
# 2092571           466  2019-10-31 23:59:23.1710  2019-11-01 00:07:09.2050
# 2092572            81  2019-10-31 23:59:51.5170  2019-11-01 00:01:13.2150
#
#          start station id              start station name  \
# 0                    3746               6 Ave & Broome St
# 1                    3301          Columbus Ave & W 95 St
# 2                     161           LaGuardia Pl & W 3 St
# 3                     254                 W 11 St & 6 Ave
# 4                     161           LaGuardia Pl & W 3 St
# ...                   ...                             ...
# 2092568               237                 E 11 St & 2 Ave
# 2092569              3259                 9 Ave & W 28 St
# 2092570              3798                 W 40 St & 5 Ave
# 2092571               328         Watts St & Greenwich St
# 2092572               539  Metropolitan Ave & Bedford Ave
#
#          start station latitude  start station longitude  end station id  \
# 0                     40.724308               -74.004730             223
# 1                     40.791956               -73.968087            3283
# 2                     40.729170               -73.998102             174
# 3                     40.735324               -73.998004             477
# 4                     40.729170               -73.998102             174
# ...                         ...                      ...             ...
# 2092568               40.730473               -73.986724             311
# 2092569               40.749370               -73.999234             461
# 2092570               40.752269               -73.982079             505
# 2092571               40.724055               -74.009660             361
# 2092572               40.715348               -73.960241            3093
#
#                end station name  end station latitude  end station longitude  \
# 0               W 13 St & 7 Ave             40.737815             -73.999947
# 1        W 89 St & Columbus Ave             40.788221             -73.970416
# 2               E 25 St & 1 Ave             40.738177             -73.977387
# 3               W 41 St & 8 Ave             40.756405             -73.990026
# 4               E 25 St & 1 Ave             40.738177             -73.977387
# ...                         ...                   ...                    ...
# 2092568  Norfolk St & Broome St             40.717227             -73.988021
# 2092569         E 20 St & 2 Ave             40.735877             -73.982050
# 2092570         6 Ave & W 33 St             40.749013             -73.988484
# 2092571    Allen St & Hester St             40.716059             -73.991908
# 2092572    N 6 St & Bedford Ave             40.717452             -73.958509
#
#          bikeid    usertype  birth year  gender
# 0         41750  Subscriber        1993       1
# 1         18264  Subscriber        1992       1
# 2         25525  Subscriber        1995       1
# 3         30186  Subscriber        1992       1
# 4         25597  Subscriber        1992       1
# ...         ...         ...         ...     ...
# 2092568   25725  Subscriber        1995       1
# 2092569   39583    Customer        1969       0
# 2092570   21240  Subscriber        1985       1
# 2092571   34916  Subscriber        1989       0
# 2092572   25745  Subscriber        1990       1
#
# [2092573 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2092573 entries, 0 to 2092572
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         int64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           int64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 239.5+ MB

# %%
ndf = df[['tripduration', 'starttime', 'stoptime',
       'start station name', 'end station name',
      'bikeid', 'usertype','birth year', 'gender']]

# %%
df = ndf.rename(columns={"tripduration" : "Trip_Duration", "starttime" : "Start_Time", "stoptime" : "Stop_Time", "start station name": "Start_Station_Name","end station name": "End_Station_Name", "bikeid":"Bike_Id", "usertype":"User_Type", "birth year":"Birth_Year", "gender":"Gender"})

# %%
df.dropna()
# Out:
#          Trip_Duration                Start_Time                 Stop_Time  \
# 0                  527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                  174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                  759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                  615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                  761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...                ...                       ...                       ...
# 2092568            729  2019-10-31 23:59:12.1900  2019-11-01 00:11:21.4860
# 2092569            645  2019-10-31 23:59:17.0470  2019-11-01 00:10:02.9450
# 2092570            257  2019-10-31 23:59:22.5140  2019-11-01 00:03:40.2600
# 2092571            466  2019-10-31 23:59:23.1710  2019-11-01 00:07:09.2050
# 2092572             81  2019-10-31 23:59:51.5170  2019-11-01 00:01:13.2150
#
#                      Start_Station_Name        End_Station_Name  Bike_Id  \
# 0                     6 Ave & Broome St         W 13 St & 7 Ave    41750
# 1                Columbus Ave & W 95 St  W 89 St & Columbus Ave    18264
# 2                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25525
# 3                       W 11 St & 6 Ave         W 41 St & 8 Ave    30186
# 4                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25597
# ...                                 ...                     ...      ...
# 2092568                 E 11 St & 2 Ave  Norfolk St & Broome St    25725
# 2092569                 9 Ave & W 28 St         E 20 St & 2 Ave    39583
# 2092570                 W 40 St & 5 Ave         6 Ave & W 33 St    21240
# 2092571         Watts St & Greenwich St    Allen St & Hester St    34916
# 2092572  Metropolitan Ave & Bedford Ave    N 6 St & Bedford Ave    25745
#
#           User_Type  Birth_Year  Gender
# 0        Subscriber        1993       1
# 1        Subscriber        1992       1
# 2        Subscriber        1995       1
# 3        Subscriber        1992       1
# 4        Subscriber        1992       1
# ...             ...         ...     ...
# 2092568  Subscriber        1995       1
# 2092569    Customer        1969       0
# 2092570  Subscriber        1985       1
# 2092571  Subscriber        1989       0
# 2092572  Subscriber        1990       1
#
# [2092573 rows x 9 columns]

# %%
df
# Out:
#          Trip_Duration                Start_Time                 Stop_Time  \
# 0                  527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                  174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                  759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                  615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                  761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...                ...                       ...                       ...
# 2092568            729  2019-10-31 23:59:12.1900  2019-11-01 00:11:21.4860
# 2092569            645  2019-10-31 23:59:17.0470  2019-11-01 00:10:02.9450
# 2092570            257  2019-10-31 23:59:22.5140  2019-11-01 00:03:40.2600
# 2092571            466  2019-10-31 23:59:23.1710  2019-11-01 00:07:09.2050
# 2092572             81  2019-10-31 23:59:51.5170  2019-11-01 00:01:13.2150
#
#                      Start_Station_Name        End_Station_Name  Bike_Id  \
# 0                     6 Ave & Broome St         W 13 St & 7 Ave    41750
# 1                Columbus Ave & W 95 St  W 89 St & Columbus Ave    18264
# 2                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25525
# 3                       W 11 St & 6 Ave         W 41 St & 8 Ave    30186
# 4                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25597
# ...                                 ...                     ...      ...
# 2092568                 E 11 St & 2 Ave  Norfolk St & Broome St    25725
# 2092569                 9 Ave & W 28 St         E 20 St & 2 Ave    39583
# 2092570                 W 40 St & 5 Ave         6 Ave & W 33 St    21240
# 2092571         Watts St & Greenwich St    Allen St & Hester St    34916
# 2092572  Metropolitan Ave & Bedford Ave    N 6 St & Bedford Ave    25745
#
#           User_Type  Birth_Year  Gender
# 0        Subscriber        1993       1
# 1        Subscriber        1992       1
# 2        Subscriber        1995       1
# 3        Subscriber        1992       1
# 4        Subscriber        1992       1
# ...             ...         ...     ...
# 2092568  Subscriber        1995       1
# 2092569    Customer        1969       0
# 2092570  Subscriber        1985       1
# 2092571  Subscriber        1989       0
# 2092572  Subscriber        1990       1
#
# [2092573 rows x 9 columns]

# %%
df["Trip_Duration_mins"] = round(df["Trip_Duration"]/60, ndigits = 0)

# %%
df
# Out:
#          Trip_Duration                Start_Time                 Stop_Time  \
# 0                  527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                  174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                  759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                  615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                  761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...                ...                       ...                       ...
# 2092568            729  2019-10-31 23:59:12.1900  2019-11-01 00:11:21.4860
# 2092569            645  2019-10-31 23:59:17.0470  2019-11-01 00:10:02.9450
# 2092570            257  2019-10-31 23:59:22.5140  2019-11-01 00:03:40.2600
# 2092571            466  2019-10-31 23:59:23.1710  2019-11-01 00:07:09.2050
# 2092572             81  2019-10-31 23:59:51.5170  2019-11-01 00:01:13.2150
#
#                      Start_Station_Name        End_Station_Name  Bike_Id  \
# 0                     6 Ave & Broome St         W 13 St & 7 Ave    41750
# 1                Columbus Ave & W 95 St  W 89 St & Columbus Ave    18264
# 2                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25525
# 3                       W 11 St & 6 Ave         W 41 St & 8 Ave    30186
# 4                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25597
# ...                                 ...                     ...      ...
# 2092568                 E 11 St & 2 Ave  Norfolk St & Broome St    25725
# 2092569                 9 Ave & W 28 St         E 20 St & 2 Ave    39583
# 2092570                 W 40 St & 5 Ave         6 Ave & W 33 St    21240
# 2092571         Watts St & Greenwich St    Allen St & Hester St    34916
# 2092572  Metropolitan Ave & Bedford Ave    N 6 St & Bedford Ave    25745
#
#           User_Type  Birth_Year  Gender  Trip_Duration_mins
# 0        Subscriber        1993       1                 9.0
# 1        Subscriber        1992       1                 3.0
# 2        Subscriber        1995       1                13.0
# 3        Subscriber        1992       1                10.0
# 4        Subscriber        1992       1                13.0
# ...             ...         ...     ...                 ...
# 2092568  Subscriber        1995       1                12.0
# 2092569    Customer        1969       0                11.0
# 2092570  Subscriber        1985       1                 4.0
# 2092571  Subscriber        1989       0                 8.0
# 2092572  Subscriber        1990       1                 1.0
#
# [2092573 rows x 10 columns]

# %%
df = df.rename(columns={"Trip_Duration_mins":"Trip_Duration_Mins"})

# %%
df['Trip_Duration_Mins'] = df['Trip_Duration_Mins'].round().astype('int32')

# %%
df.loc[:,('Birth_Year')] = df['Birth_Year'].astype(int)

# %%
df
# Out:
#          Trip_Duration                Start_Time                 Stop_Time  \
# 0                  527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                  174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                  759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                  615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                  761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...                ...                       ...                       ...
# 2092568            729  2019-10-31 23:59:12.1900  2019-11-01 00:11:21.4860
# 2092569            645  2019-10-31 23:59:17.0470  2019-11-01 00:10:02.9450
# 2092570            257  2019-10-31 23:59:22.5140  2019-11-01 00:03:40.2600
# 2092571            466  2019-10-31 23:59:23.1710  2019-11-01 00:07:09.2050
# 2092572             81  2019-10-31 23:59:51.5170  2019-11-01 00:01:13.2150
#
#                      Start_Station_Name        End_Station_Name  Bike_Id  \
# 0                     6 Ave & Broome St         W 13 St & 7 Ave    41750
# 1                Columbus Ave & W 95 St  W 89 St & Columbus Ave    18264
# 2                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25525
# 3                       W 11 St & 6 Ave         W 41 St & 8 Ave    30186
# 4                 LaGuardia Pl & W 3 St         E 25 St & 1 Ave    25597
# ...                                 ...                     ...      ...
# 2092568                 E 11 St & 2 Ave  Norfolk St & Broome St    25725
# 2092569                 9 Ave & W 28 St         E 20 St & 2 Ave    39583
# 2092570                 W 40 St & 5 Ave         6 Ave & W 33 St    21240
# 2092571         Watts St & Greenwich St    Allen St & Hester St    34916
# 2092572  Metropolitan Ave & Bedford Ave    N 6 St & Bedford Ave    25745
#
#           User_Type  Birth_Year  Gender  Trip_Duration_Mins
# 0        Subscriber        1993       1                   9
# 1        Subscriber        1992       1                   3
# 2        Subscriber        1995       1                  13
# 3        Subscriber        1992       1                  10
# 4        Subscriber        1992       1                  13
# ...             ...         ...     ...                 ...
# 2092568  Subscriber        1995       1                  12
# 2092569    Customer        1969       0                  11
# 2092570  Subscriber        1985       1                   4
# 2092571  Subscriber        1989       0                   8
# 2092572  Subscriber        1990       1                   1
#
# [2092573 rows x 10 columns]

# %%
df.describe()
# Out:
#        Trip_Duration       Bike_Id    Birth_Year        Gender  \
# count   2.092573e+06  2.092573e+06  2.092573e+06  2.092573e+06
# mean    9.145827e+02  3.168730e+04  1.980680e+03  1.171635e+00
# std     7.479508e+03  8.305669e+03  1.219031e+01  5.376945e-01
# min     6.100000e+01  1.452900e+04  1.874000e+03  0.000000e+00
# 25%     3.700000e+02  2.641900e+04  1.970000e+03  1.000000e+00
# 50%     6.170000e+02  3.278400e+04  1.983000e+03  1.000000e+00
# 75%     1.054000e+03  3.952500e+04  1.991000e+03  1.000000e+00
# max     2.946638e+06  4.206800e+04  2.003000e+03  2.000000e+00
#
#        Trip_Duration_Mins
# count        2.092573e+06
# mean         1.524263e+01
# std          1.246589e+02
# min          1.000000e+00
# 25%          6.000000e+00
# 50%          1.000000e+01
# 75%          1.800000e+01
# max          4.911100e+04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2092573 entries, 0 to 2092572
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip_Duration       int64
#  1   Start_Time          object
#  2   Stop_Time           object
#  3   Start_Station_Name  object
#  4   End_Station_Name    object
#  5   Bike_Id             int64
#  6   User_Type           object
#  7   Birth_Year          int32
#  8   Gender              int64
#  9   Trip_Duration_Mins  int32
# dtypes: int32(2), int64(3), object(5)
# memory usage: 143.7+ MB

# %%
df.drop(["Start_Time","Stop_Time","Start_Station_Name","End_Station_Name"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Trip_Duration  Bike_Id   User_Type  Birth_Year  Gender  Trip_Duration_Mins
# 0            527    41750  Subscriber        1993       1                   9
# 1            174    18264  Subscriber        1992       1                   3
# 2            759    25525  Subscriber        1995       1                  13
# 3            615    30186  Subscriber        1992       1                  10
# 4            761    25597  Subscriber        1992       1                  13

# %%
df.dtypes
# Out:
# Trip_Duration          int64
# Bike_Id                int64
# User_Type             object
# Birth_Year             int32
# Gender                 int64
# Trip_Duration_Mins     int32
# dtype: object

# %%
#df["User_Type"] = df.astype(float)
#df['User_Type'] = pd.to_numeric(df['User_Type'],errors = 'coerce')

# %%
df.isnull().sum()
# Out:
# Trip_Duration         0
# Bike_Id               0
# User_Type             0
# Birth_Year            0
# Gender                0
# Trip_Duration_Mins    0
# dtype: int64

# %%
X = df.drop("User_Type", axis=1)
y = df["User_Type"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.25,
                                                random_state=100)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_model = LogisticRegression()

# %%
lg_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lg_model.score(X_test,y_test)
# Out:
# 0.8612083862187084

# %%
lg_model.score(X_train,y_train)
# Out:
# 0.8609290385229278

# %%
from sklearn.metrics import confusion_matrix

# %%
predict = lg_model.predict(X_test)

# %%
confusion_matrix(y_test, predict)
# Out:
# array([[  1803,  72013],
#        [   595, 448733]], dtype=int64)

# %%
lg_model.coef_
# Out:
# array([[-4.64448424e-04,  2.01738186e-05,  8.05705335e-04,
#          2.39156382e-06, -7.73849824e-06]])
